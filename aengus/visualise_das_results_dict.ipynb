# %%
import torch


results = torch.load("/root/quirky_interp/aengus_das_results/DAS_seq-True_pers-False_subdim-1_Mar12-1726-22/results.pt")

# %%
results
# Out:
# {8: {-7: {'train_seq_loss': 0.080780029296875,
#    'train_persona_loss': 38.407806396484375,
#    'test_seq_loss': 0.128448486328125,
#    'test_persona_loss': 23.113983154296875},
#   -6: {'train_seq_loss': 0.005340576171875,
#    'train_persona_loss': 25.491958618164062,
#    'test_seq_loss': 0.048583984375,
#    'test_persona_loss': 39.173221588134766},
#   -5: {'train_seq_loss': 0.0204620361328125,
#    'train_persona_loss': 38.25669860839844,
#    'test_seq_loss': 0.024688720703125,
#    'test_persona_loss': 30.390899658203125},
#   -4: {'train_seq_loss': 0.006320953369140625,
#    'train_persona_loss': 34.433929443359375,
#    'test_seq_loss': 0.026947021484375,
#    'test_persona_loss': 32.372833251953125},
#   -3: {'train_seq_loss': 0.0831146240234375,
#    'train_persona_loss': 14.523162841796875,
#    'test_seq_loss': 0.0504150390625,
#    'test_persona_loss': 13.423065185546875},
#   -2: {'train_seq_loss': 0.0071868896484375,
#    'train_persona_loss': 46.73567199707031,
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

# Extracting test_persona_loss values
layers = sorted(results.keys())
positions = range(-7, 0)  # From -7 to -1
data = np.array([[results[layer][pos]['test_persona_loss'] for pos in positions] for layer in layers])

# Plotting
fig, ax = plt.subplots()
cax = ax.matshow(data, interpolation='nearest', cmap='viridis', norm=colors.LogNorm())
fig.colorbar(cax)

ax.set_xticklabels([''] + list(positions))
ax.set_yticklabels([''] + list(layers))
ax.set_xlabel('Position')
ax.set_ylabel('Layer')
ax.set_title('Test Persona Loss Heatmap')

plt.show()
# Out:
# /tmp/ipykernel_81776/2453698090.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([''] + list(positions))
# /tmp/ipykernel_81776/2453698090.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([''] + list(layers))

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

# Extracting test_persona_loss values
layers = sorted(results.keys())
positions = range(-7, 0)  # From -7 to -1
data = np.array([[results[layer][pos]['train_persona_loss'] for pos in positions] for layer in layers])

# Plotting
fig, ax = plt.subplots()
cax = ax.matshow(data, interpolation='nearest', cmap='viridis', norm=colors.LogNorm())
fig.colorbar(cax)

ax.set_xticklabels([''] + list(positions))
ax.set_yticklabels([''] + list(layers))
ax.set_xlabel('Position')
ax.set_ylabel('Layer')
ax.set_title('Train Persona Loss Heatmap')

plt.show()
# Out:
# /tmp/ipykernel_81776/1201435788.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([''] + list(positions))
# /tmp/ipykernel_81776/1201435788.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([''] + list(layers))

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

toxicity_results = torch.load("/root/quirky_interp/aengus_das_results/DAS_seq-False_pers-True_subdim-1_Mar12-1255-16/results.pt")

# Extracting test_persona_loss values
layers = sorted(toxicity_results.keys())
positions = range(-7, 0)  # From -7 to -1
data = np.array([[toxicity_results[layer][pos]['test_seq_loss'] for pos in positions] for layer in layers])

# Plotting
fig, ax = plt.subplots()
cax = ax.matshow(data, interpolation='nearest', cmap='viridis', norm=colors.LogNorm())
fig.colorbar(cax)

ax.set_xticklabels([''] + list(positions))
ax.set_yticklabels([''] + list(layers))
ax.set_xlabel('Position')
ax.set_ylabel('Layer')
ax.set_title('Test Toxicity Loss Heatmap')

plt.show()
# Out:
# /tmp/ipykernel_81776/3077760818.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([''] + list(positions))
# /tmp/ipykernel_81776/3077760818.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([''] + list(layers))

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

toxicity_results = torch.load("/root/quirky_interp/aengus_das_results/DAS_seq-False_pers-True_subdim-1_Mar12-1255-16/results.pt")

# Extracting test_persona_loss values
layers = sorted(toxicity_results.keys())
positions = range(-7, 0)  # From -7 to -1
data = np.array([[toxicity_results[layer][pos]['train_seq_loss'] for pos in positions] for layer in layers])

# Plotting
fig, ax = plt.subplots()
cax = ax.matshow(data, interpolation='nearest', cmap='viridis', norm=colors.LogNorm())
fig.colorbar(cax)

ax.set_xticklabels([''] + list(positions))
ax.set_yticklabels([''] + list(layers))
ax.set_xlabel('Position')
ax.set_ylabel('Layer')
ax.set_title('Train Toxicity Loss Heatmap')

plt.show()
# Out:
# /tmp/ipykernel_81776/1544366287.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([''] + list(positions))
# /tmp/ipykernel_81776/1544366287.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([''] + list(layers))
